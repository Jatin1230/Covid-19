# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_json("https://www.mohfw.gov.in/data/datanew.json")
df.head()
# Out:
#    sno                   state_name  active  positive    cured  death  \
# 0    1  Andaman and Nicobar Islands       0     10766    10637    129
# 1    2               Andhra Pradesh       0   2340676  2325943  14733
# 2    3            Arunachal Pradesh       0     67049    66753    296
# 3    4                        Assam       0    746150   738115   8035
# 4    5                        Bihar       1    855262   842947  12314
#
#    new_active  new_positive  new_cured  new_death death_reconsille total  \
# 0           0         10766      10637        129
# 1           0       2340676    2325943      14733
# 2           0         67049      66753        296
# 3           0        746150     738115       8035
# 4           1        855262     842947      12314
#
#    state_code  actualdeath24hrs
# 0          35                 0
# 1          28                 0
# 2          12                 0
# 3          18                 0
# 4          10                 0

# %%
df.tail()
# Out:
#     sno     state_name  active  positive     cured   death  new_active  \
# 32   33        Tripura       2    108473    107529     942           6
# 33   34    Uttarakhand       0    452562    444794    7768           0
# 34   35  Uttar Pradesh      60   2145416   2121649   23707          58
# 35   36    West Bengal     193   2125988   2104241   21554         192
# 36   37                   1450  44997673  44463021  531922        1436
#
#     new_positive  new_cured  new_death death_reconsille total  state_code  \
# 32        108477     107529        942                                 16
# 33        452562     444794       7768                                  5
# 34       2145416    2121650      23708                      1           9
# 35       2125996    2104250      21554                                 19
# 36      44997706   44463066     531924                      2           0
#
#     actualdeath24hrs
# 32                 0
# 33                 0
# 34                 1
# 35                 0
# 36                 2

# %%
df=df.iloc[:36,1:]
df
# Out:
#                                   state_name  active  positive    cured  \
# 0                Andaman and Nicobar Islands       0     10766    10637
# 1                             Andhra Pradesh       0   2340676  2325943
# 2                          Arunachal Pradesh       0     67049    66753
# 3                                      Assam       0    746150   738115
# 4                                      Bihar       1    855262   842947
# 5                                 Chandigarh       0    100693    99508
# 6                               Chhattisgarh       3   1187694  1173501
# 7   Dadra and Nagar Haveli and Daman and Diu       0     11592    11588
# 8                                      Delhi       9   2040847  2014172
# 9                                       Goa*       1    263334   259319
# 10                                   Gujarat       3   1291370  1280288
# 11                                   Haryana      26   1078890  1068109
# 12                          Himachal Pradesh      11    322884   318632
# 13                         Jammu and Kashmir       0    482023   477231
# 14                                 Jharkhand       0    443825   438491
# 15                                 Karnataka       6   4088724  4048361
# 16                                 Kerala***    1007   6907158  6834205
# 17                                    Ladakh       5     29592    29356
# 18                               Lakshadweep       0     11415    11363
# 19                            Madhya Pradesh       0   1056351  1045565
# 20                               Maharashtra      88   8170364  8021719
# 21                                   Manipur       1    140032   137882
# 22                                 Meghalaya       2     96969    95339
# 23                                   Mizoram       0    239559   238825
# 24                                  Nagaland       0     36032    35250
# 25                                    Odisha       8   1348390  1339114
# 26                                Puducherry       0    177545   175564
# 27                                  Punjab**       1    793637   773071
# 28                                 Rajasthan       0   1326462  1316726
# 29                                    Sikkim       9     44908    44399
# 30                                Tamil Nadu       4   3610635  3572550
# 31                                 Telangana      10    844406   840285
# 32                                   Tripura       2    108473   107529
# 33                               Uttarakhand       0    452562   444794
# 34                             Uttar Pradesh      60   2145416  2121649
# 35                               West Bengal     193   2125988  2104241
#
#      death  new_active  new_positive  new_cured  new_death death_reconsille  \
# 0      129           0         10766      10637        129
# 1    14733           0       2340676    2325943      14733
# 2      296           0         67049      66753        296
# 3     8035           0        746150     738115       8035
# 4    12314           1        855262     842947      12314
# 5     1185           0        100693      99508       1185
# 6    14190           3       1187694    1173501      14190
# 7        4           0         11592      11588          4
# 8    26666           4       2040847    2014177      26666
# 9     4014           0        263334     259320       4014
# 10   11079           2       1291370    1280289      11079
# 11   10755          26       1078890    1068109      10755
# 12    4241          10        322885     318634       4241
# 13    4792           0        482023     477231       4792
# 14    5334           0        443825     438491       5334
# 15   40357           6       4088726    4048363      40357
# 16   71946        1005       6907160    6834208      71947
# 17     231           6         29593      29356        231
# 18      52           0         11415      11363         52
# 19   10786           0       1056351    1045565      10786
# 20  148557          83       8170373    8021733     148557
# 21    2149           1        140032     137882       2149
# 22    1628           1         96969      95340       1628
# 23     734           0        239559     238825        734
# 24     782           0         36032      35250        782
# 25    9215          10       1348393    1339115       9215
# 26    1981           0        177545     175564       1981
# 27   19338           1        793637     773071      19338
# 28    9736           0       1326462    1316726       9736
# 29     500           8         44908      44400        500
# 30   38081           4       3610637    3572552      38081
# 31    4111           9        844407     840287       4111
# 32     942           6        108477     107529        942
# 33    7768           0        452562     444794       7768
# 34   23707          58       2145416    2121650      23708
# 35   21554         192       2125996    2104250      21554
#
#    total  state_code  actualdeath24hrs
# 0                 35                 0
# 1                 28                 0
# 2                 12                 0
# 3                 18                 0
# 4                 10                 0
# 5                  4                 0
# 6                 22                 0
# 7                 26                 0
# 8                  7                 0
# 9                 30                 0
# 10                24                 0
# 11                 6                 0
# 12                 2                 0
# 13                 1                 0
# 14                20                 0
# 15                29                 0
# 16     1          32                 1
# 17                37                 0
# 18                31                 0
# 19                23                 0
# 20                27                 0
# 21                14                 0
# 22                17                 0
# 23                15                 0
# 24                13                 0
# 25                21                 0
# 26                34                 0
# 27                 3                 0
# 28                 8                 0
# 29                11                 0
# 30                33                 0
# 31                36                 0
# 32                16                 0
# 33                 5                 0
# 34     1           9                 1
# 35                19                 0

# %%
plt.figure(figsize=(20,20))
sns.barplot(x=df["death"],y=df["state_name"])
# Out:
# <AxesSubplot:xlabel='death', ylabel='state_name'>

# %%
df1=df.iloc[:,1:4]
df1.plot.barh(figsize=(20,20))
# Out:
# <AxesSubplot:>

# %%
df=df.drop(['death_reconsille','total','actualdeath24hrs'],axis=1)
df.head()
# Out:
#                     state_name  active  positive    cured  death  new_active  \
# 0  Andaman and Nicobar Islands       0     10766    10637    129           0
# 1               Andhra Pradesh       0   2340676  2325943  14733           0
# 2            Arunachal Pradesh       0     67049    66753    296           0
# 3                        Assam       0    746150   738115   8035           0
# 4                        Bihar       1    855262   842947  12314           1
#
#    new_positive  new_cured  new_death  state_code
# 0         10766      10637        129          35
# 1       2340676    2325943      14733          28
# 2         67049      66753        296          12
# 3        746150     738115       8035          18
# 4        855262     842947      12314          10

# %%
data_active=df.sort_values(["active"],ascending=False)
data_active=data_active.iloc[:7,:]
data_active
# Out:
#           state_name  active  positive    cured   death  new_active  \
# 16         Kerala***    1007   6907158  6834205   71946        1005
# 35       West Bengal     193   2125988  2104241   21554         192
# 20       Maharashtra      88   8170364  8021719  148557          83
# 34     Uttar Pradesh      60   2145416  2121649   23707          58
# 11           Haryana      26   1078890  1068109   10755          26
# 12  Himachal Pradesh      11    322884   318632    4241          10
# 31         Telangana      10    844406   840285    4111           9
#
#     new_positive  new_cured  new_death  state_code
# 16       6907160    6834208      71947          32
# 35       2125996    2104250      21554          19
# 20       8170373    8021733     148557          27
# 34       2145416    2121650      23708           9
# 11       1078890    1068109      10755           6
# 12        322885     318634       4241           2
# 31        844407     840287       4111          36

# %%
explode = [0.1,0,0,0,0,0,0]
colors = ["r","b","y", "g", "c","m","brown"]
textprops = {"fontsize":8}
wedgeprops = {"linewidth":1, "width":1,"edgecolor":"black"}
plt.figure(figsize=(16,9))
fontdict = {"fontsize":10}
plt.title("Top seven corrona affected states \n Total active cases in india  : {} \n Total active cases in these states {} \n Total percentage of active cases in these states :  {}%".format(sum(df["active"]) ,
        sum(data_active["active"])  , round(sum(data_active["active"]) / sum(df["active"])  , 4)* 100 ), fontdict = fontdict)
plt.pie(data_active["active"], labels = data_active["state_name"],explode = explode,colors = colors, autopct= "%0.2f%%",radius = 1,
        wedgeprops = wedgeprops , textprops = textprops, pctdistance = 0.6,labeldistance = 1.1 , rotatelabels=True )
plt.legend(loc = 0)
plt.show()

# %%
def top_seven_states_index(x):
    positive=list(x)
    top_seven_states=[]
    index_active=[]
    state_active=[]
    for i in range(7):
        top_seven_states.append(max(positive))
        positive.remove(max(positive))
    
    for i in range(len(x)):
        for j in range(len (top_seven_states)):
            if x[i]==top_seven_states[j]:
                index_active.append(i)
                
    for i in index_active:
        state_active.append(df['state_name'][i])
        
    for i in index_active:
        top_seven_states.append(x[i])
        
    return top_seven_states,state_active,index_active

# %%
top_seven_states_active,state_name,index_active=top_seven_states_index(df["active"])

# %%
print(index_active)
print(f"top seven states_active : {top_seven_states_active}")
print(f"states_name : {state_name}")
# Out:
# [11, 12, 16, 20, 31, 34, 35]
# top seven states_active : [1007, 193, 88, 60, 26, 11, 10, 26, 11, 1007, 88, 10, 60, 193]
# states_name : ['Haryana', 'Himachal Pradesh', 'Kerala***', 'Maharashtra', 'Telangana', 'Uttar Pradesh', 'West Bengal']

# %%
top_seven_states_cured , state_cured , index_cured = top_seven_states_index(df["cured"])

# %%
print(index_cured)
print(f"top seven states_cured : {top_seven_states_cured}")
print(f"states_name : {state_cured}")
# Out:
# [1, 15, 16, 20, 30, 34, 35]
# top seven states_cured : [8021719, 6834205, 4048361, 3572550, 2325943, 2121649, 2104241, 2325943, 4048361, 6834205, 8021719, 3572550, 2121649, 2104241]
# states_name : ['Andhra Pradesh', 'Karnataka', 'Kerala***', 'Maharashtra', 'Tamil Nadu', 'Uttar Pradesh', 'West Bengal']

# %%
top_seven_states_death , state_death , index_death = top_seven_states_index(df["death"])

# %%
print(index_cured)
print(f"top seven states_death : {top_seven_states_death}")
print(f"states_death : {state_death}")
# Out:
# [1, 15, 16, 20, 30, 34, 35]
# top seven states_death : [148557, 71946, 40357, 38081, 26666, 23707, 21554, 26666, 40357, 71946, 148557, 38081, 23707, 21554]
# states_death : ['Delhi', 'Karnataka', 'Kerala***', 'Maharashtra', 'Tamil Nadu', 'Uttar Pradesh', 'West Bengal']
